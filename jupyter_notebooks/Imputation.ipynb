# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
# Load files into a pandas dataframe
train = pd.read_csv('../data/Train.csv')
test = pd.read_csv('../data/Test.csv')
ss = pd.read_csv('../data/SampleSubmission.csv')

# %% [markdown]
# # Train Data

# %%
ax = train.isna().sum().sort_values().plot(kind = 'barh', figsize = (10, 7))
plt.title('Percentage of Missing Values Per Column in Train Set', fontdict={'size':15})
for p in ax.patches:
    percentage ='{:,.0f}%'.format((p.get_width()/train.shape[0])*100)
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %%
train['Subject_Car_Make'] = train['Subject_Car_Make'].replace('.', np.nan)

# %%
def clean_age(age):
    if pd.isna(age) or age < 0 or age > 100:
        return np.nan
    return age

train['Age'] = train['Age'].apply(clean_age)
train['Age'] = train['Age'].fillna(round(train['Age'].mean(), 0))

# %%
train['Gender'] = train['Gender'].fillna(train['Gender'].mode()[0])

mapper = {'Entity':'Other', 'Joint Gender':'Other', 'NOT STATED':'Other', 'NO GENDER': 'Other', 'SEX':"Other"}
train.Gender = train.Gender.replace(mapper)

# %%
train['Policy_Start_Date'] = pd.to_datetime(train['Policy_Start_Date'])
train['Policy_End_Date'] = pd.to_datetime(train['Policy_End_Date'])
train['First_Transaction_Date'] = pd.to_datetime(train['First_Transaction_Date'])

train['StartMonth'] = train['Policy_Start_Date'].dt.month
train['EndMonth'] = train['Policy_End_Date'].dt.month
train['FirstMonth'] = train['First_Transaction_Date'].dt.month

train['StartDay'] = train['Policy_Start_Date'].dt.day
train['EndDay'] = train['Policy_End_Date'].dt.day
train['FirstDay'] = train['First_Transaction_Date'].dt.day

# %%
train
# Out:
#                ID Policy_Start_Date Policy_End_Date  Gender   Age  \
# 0      ID_0040R73        2010-05-14      2011-05-13    Male  30.0
# 1      ID_0046BNK        2010-11-29      2011-11-28  Female  79.0
# 2      ID_005QMC3        2010-03-21      2011-03-20    Male  43.0
# 3      ID_0079OHW        2010-08-21      2011-08-20    Male   2.0
# 4      ID_00BRP63        2010-08-29      2010-12-31   Other  20.0
# ...           ...               ...             ...     ...   ...
# 12074  ID_ZZA1SES        2010-05-25      2011-05-24  Female  30.0
# 12075  ID_ZZDAC3K        2010-10-03      2011-10-02  Female  59.0
# 12076  ID_ZZIU2XC        2010-10-10      2011-10-08    Male  34.0
# 12077  ID_ZZRQ1NF        2010-02-27      2011-02-26    Male  41.0
# 12078  ID_ZZWRIIE        2010-07-01      2011-06-30  Female  46.0
#
#       First_Transaction_Date  No_Pol Car_Category Subject_Car_Colour  \
# 0                 2010-05-14       1       Saloon              Black
# 1                 2010-11-29       1         JEEP               Grey
# 2                 2010-03-21       1       Saloon                Red
# 3                 2010-08-21       1          NaN                NaN
# 4                 2010-08-29       3          NaN                NaN
# ...                      ...     ...          ...                ...
# 12074             2010-05-25       1          NaN              Black
# 12075             2010-10-03       1          NaN                NaN
# 12076             2010-10-10       1          NaN                NaN
# 12077             2010-02-27       2          NaN              White
# 12078             2010-07-01       2         JEEP              Black
#
#       Subject_Car_Make         LGA_Name        State  ProductName  target  \
# 0               TOYOTA              NaN          NaN  Car Classic       0
# 1               TOYOTA              NaN          NaN  Car Classic       1
# 2               TOYOTA              NaN          NaN  Car Classic       0
# 3                  NaN              NaN          NaN      CarSafe       0
# 4                  NaN            Lagos        Lagos        Muuve       1
# ...                ...              ...          ...          ...     ...
# 12074      Range Rover      Ibeju/Lekki  Ibeju-Lekki  Car Classic       1
# 12075              NaN              NaN          NaN  Car Classic       0
# 12076              NaN              NaN          NaN      CarSafe       0
# 12077           TOYOTA  Victoria Island        Lagos         CVTP       0
# 12078       Land Rover     Lagos Island        Lagos  Car Classic       0
#
#        StartMonth  EndMonth  FirstMonth  StartDay  EndDay  FirstDay
# 0               5         5           5        14      13        14
# 1              11        11          11        29      28        29
# 2               3         3           3        21      20        21
# 3               8         8           8        21      20        21
# 4               8        12           8        29      31        29
# ...           ...       ...         ...       ...     ...       ...
# 12074           5         5           5        25      24        25
# 12075          10        10          10         3       2         3
# 12076          10        10          10        10       8        10
# 12077           2         2           2        27      26        27
# 12078           7         6           7         1      30         1
#
# [12079 rows x 20 columns]

# %%
train = train.sort_values(by='Policy_Start_Date')
train
# Out:
#                ID Policy_Start_Date Policy_End_Date  Gender   Age  \
# 8010   ID_O51ZQ1B        2001-12-11      2011-12-10  Female  37.0
# 10526  ID_VJ1FAVO        2002-03-25      2011-03-24    Male  37.0
# 10234  ID_ULWS8VL        2003-04-13      2011-04-12    Male  41.0
# 12066  ID_ZYKGSP7        2003-12-21      2034-05-20    Male  48.0
# 8124   ID_OEWBKGF        2005-08-05      2011-09-29  Female  44.0
# ...           ...               ...             ...     ...   ...
# 7479   ID_MLGO8DZ        2010-12-31      2011-06-30    Male  51.0
# 1997   ID_62LBOWI        2010-12-31      2011-12-30    Male  44.0
# 11299  ID_XR8F115        2010-12-31      2011-12-30    Male  37.0
# 2919   ID_8P2UGYO        2010-12-31      2011-12-30    Male  20.0
# 2886   ID_8MNXRC6        2010-12-31      2011-12-16    Male  36.0
#
#       First_Transaction_Date  No_Pol Car_Category Subject_Car_Colour  \
# 8010              2001-12-11       1       Saloon              Black
# 10526             2002-03-25       1       Saloon              Black
# 10234             2003-04-13       2       Saloon              Black
# 12066             2003-12-21       2       Saloon                NaN
# 8124              2005-08-05       1          NaN                NaN
# ...                      ...     ...          ...                ...
# 7479              2010-12-31       4       Saloon              Black
# 1997              2010-12-31       1          NaN                NaN
# 11299             2010-12-31       1         JEEP                NaN
# 2919              2010-12-31       1          NaN                NaN
# 2886              2010-12-31       1       Saloon             Silver
#
#       Subject_Car_Make         LGA_Name  State  ProductName  target  \
# 8010             Honda              NaN    NaN  Car Vintage       0
# 10526           TOYOTA            Ekiti  Benue  Car Classic       0
# 10234           TOYOTA            Ikeja  Lagos  Car Vintage       0
# 12066              BMW              NaN    NaN  Car Vintage       0
# 8124              Tata             Ajah  Lagos         CVTP       0
# ...                ...              ...    ...          ...     ...
# 7479             Honda  Victoria Island  Lagos  Car Classic       0
# 1997               NaN  Victoria Island  Lagos  Car Classic       0
# 11299          Hyundai              NaN    NaN      CarSafe       0
# 2919               NaN              NaN    NaN      CarSafe       0
# 2886               Kia  Anthony Village  Lagos  Car Classic       1
#
#        StartMonth  EndMonth  FirstMonth  StartDay  EndDay  FirstDay
# 8010           12        12          12        11      10        11
# 10526           3         3           3        25      24        25
# 10234           4         4           4        13      12        13
# 12066          12         5          12        21      20        21
# 8124            8         9           8         5      29         5
# ...           ...       ...         ...       ...     ...       ...
# 7479           12         6          12        31      30        31
# 1997           12        12          12        31      30        31
# 11299          12        12          12        31      30        31
# 2919           12        12          12        31      30        31
# 2886           12        12          12        31      16        31
#
# [12079 rows x 20 columns]

# %%
train.isnull().sum()
# Out:
# ID                        0
# Policy_Start_Date         0
# Policy_End_Date           0
# Gender                    0
# Age                       0
# First_Transaction_Date    0
# No_Pol                    0
# Car_Category              0
# Subject_Car_Colour        0
# Subject_Car_Make          0
# LGA_Name                  0
# State                     0
# ProductName               0
# target                    0
# dtype: int64

# %%
def backfill_data(data, columns):
    for column in columns:
        data[column] = data[column].fillna(method='bfill')
    return data


train = train.drop(columns=['StartMonth', 'EndMonth', 'FirstMonth', 'StartDay', 'EndDay', 'FirstDay'])
                   
backfill_columns = ['Car_Category', 'Subject_Car_Colour', 'Subject_Car_Make', 'LGA_Name', 'State']
    
backfilled_data = backfill_data(train, backfill_columns)

print("Original Data:")
print(train)
print("\nBackfilled Data:")
print(backfilled_data)

backfilled_data.to_csv('./data/backfilled_data.csv', index=False)
# Out:
# Original Data:
#                ID Policy_Start_Date Policy_End_Date  Gender   Age  \
# 8010   ID_O51ZQ1B        2001-12-11      2011-12-10  Female  37.0
# 10526  ID_VJ1FAVO        2002-03-25      2011-03-24    Male  37.0
# 10234  ID_ULWS8VL        2003-04-13      2011-04-12    Male  41.0
# 12066  ID_ZYKGSP7        2003-12-21      2034-05-20    Male  48.0
# 8124   ID_OEWBKGF        2005-08-05      2011-09-29  Female  44.0
# ...           ...               ...             ...     ...   ...
# 7479   ID_MLGO8DZ        2010-12-31      2011-06-30    Male  51.0
# 1997   ID_62LBOWI        2010-12-31      2011-12-30    Male  44.0
# 11299  ID_XR8F115        2010-12-31      2011-12-30    Male  37.0
# 2919   ID_8P2UGYO        2010-12-31      2011-12-30    Male  20.0
# 2886   ID_8MNXRC6        2010-12-31      2011-12-16    Male  36.0
#
#       First_Transaction_Date  No_Pol Car_Category Subject_Car_Colour  \
# 8010              2001-12-11       1       Saloon              Black
# 10526             2002-03-25       1       Saloon              Black
# 10234             2003-04-13       2       Saloon              Black
# 12066             2003-12-21       2       Saloon               Gold
# 8124              2005-08-05       1       Saloon               Gold
# ...                      ...     ...          ...                ...
# 7479              2010-12-31       4       Saloon              Black
# 1997              2010-12-31       1         JEEP             Silver
# 11299             2010-12-31       1         JEEP             Silver
# 2919              2010-12-31       1       Saloon             Silver
# 2886              2010-12-31       1       Saloon             Silver
#
#       Subject_Car_Make         LGA_Name  State  ProductName  target
# 8010             Honda            Ekiti  Benue  Car Vintage       0
# 10526           TOYOTA            Ekiti  Benue  Car Classic       0
# 10234           TOYOTA            Ikeja  Lagos  Car Vintage       0
# 12066              BMW             Ajah  Lagos  Car Vintage       0
# 8124              Tata             Ajah  Lagos         CVTP       0
# ...                ...              ...    ...          ...     ...
# 7479             Honda  Victoria Island  Lagos  Car Classic       0
# 1997           Hyundai  Victoria Island  Lagos  Car Classic       0
# 11299          Hyundai  Anthony Village  Lagos      CarSafe       0
# 2919               Kia  Anthony Village  Lagos      CarSafe       0
# 2886               Kia  Anthony Village  Lagos  Car Classic       1
#
# [12079 rows x 14 columns]
#
# Backfilled Data:
#                ID Policy_Start_Date Policy_End_Date  Gender   Age  \
# 8010   ID_O51ZQ1B        2001-12-11      2011-12-10  Female  37.0
# 10526  ID_VJ1FAVO        2002-03-25      2011-03-24    Male  37.0
# 10234  ID_ULWS8VL        2003-04-13      2011-04-12    Male  41.0
# 12066  ID_ZYKGSP7        2003-12-21      2034-05-20    Male  48.0
# 8124   ID_OEWBKGF        2005-08-05      2011-09-29  Female  44.0
# ...           ...               ...             ...     ...   ...
# 7479   ID_MLGO8DZ        2010-12-31      2011-06-30    Male  51.0
# 1997   ID_62LBOWI        2010-12-31      2011-12-30    Male  44.0
# 11299  ID_XR8F115        2010-12-31      2011-12-30    Male  37.0
# 2919   ID_8P2UGYO        2010-12-31      2011-12-30    Male  20.0
# 2886   ID_8MNXRC6        2010-12-31      2011-12-16    Male  36.0
#
#       First_Transaction_Date  No_Pol Car_Category Subject_Car_Colour  \
# 8010              2001-12-11       1       Saloon              Black
# 10526             2002-03-25       1       Saloon              Black
# 10234             2003-04-13       2       Saloon              Black
# 12066             2003-12-21       2       Saloon               Gold
# 8124              2005-08-05       1       Saloon               Gold
# ...                      ...     ...          ...                ...
# 7479              2010-12-31       4       Saloon              Black
# 1997              2010-12-31       1         JEEP             Silver
# 11299             2010-12-31       1         JEEP             Silver
# 2919              2010-12-31       1       Saloon             Silver
# 2886              2010-12-31       1       Saloon             Silver
#
#       Subject_Car_Make         LGA_Name  State  ProductName  target
# 8010             Honda            Ekiti  Benue  Car Vintage       0
# 10526           TOYOTA            Ekiti  Benue  Car Classic       0
# 10234           TOYOTA            Ikeja  Lagos  Car Vintage       0
# 12066              BMW             Ajah  Lagos  Car Vintage       0
# 8124              Tata             Ajah  Lagos         CVTP       0
# ...                ...              ...    ...          ...     ...
# 7479             Honda  Victoria Island  Lagos  Car Classic       0
# 1997           Hyundai  Victoria Island  Lagos  Car Classic       0
# 11299          Hyundai  Anthony Village  Lagos      CarSafe       0
# 2919               Kia  Anthony Village  Lagos      CarSafe       0
# 2886               Kia  Anthony Village  Lagos  Car Classic       1
#
# [12079 rows x 14 columns]

# %%
# Check if there any missing values in test set
ax = backfilled_data.isna().sum().sort_values().plot(kind = 'barh', figsize = (8, 5))
plt.title('Percentage of Missing Values Per Column in test Set', fontdict={'size':15})
for p in ax.patches:
    percentage ='{:,.0f}%'.format((p.get_width()/backfilled_data.shape[0])*100)
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %% [markdown]
# # Test Data

# %%
ax = test.isna().sum().sort_values().plot(kind = 'barh', figsize = (8, 5))
plt.title('Percentage of Missing Values Per Column in test Set', fontdict={'size':15})
for p in ax.patches:
    percentage ='{:,.0f}%'.format((p.get_width()/test.shape[0])*100)
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %%
test['Subject_Car_Make'] = test['Subject_Car_Make'].replace('.', np.nan)

# %%
def clean_age(age):
    if pd.isna(age) or age < 0 or age > 100:
        return np.nan
    return age

test['Age'] = test['Age'].apply(clean_age)
test['Age'] = test['Age'].fillna(round(test['Age'].mean(), 0))

# %%
test['Gender'] = test['Gender'].fillna(test['Gender'].mode()[0])

mapper = {'Entity':'Other', 'Joint Gender':'Other', 'NOT STATED':'Other', 'NO GENDER': 'Other', 'SEX':"Other"}
test.Gender = test.Gender.replace(mapper)

# %%
test['Policy_Start_Date'] = pd.to_datetime(test['Policy_Start_Date'])
test['Policy_End_Date'] = pd.to_datetime(test['Policy_End_Date'])
test['First_Transaction_Date'] = pd.to_datetime(test['First_Transaction_Date'])

test['StartMonth'] = test['Policy_Start_Date'].dt.month
test['EndMonth'] = test['Policy_End_Date'].dt.month
test['FirstMonth'] = test['First_Transaction_Date'].dt.month

test['StartDay'] = test['Policy_Start_Date'].dt.day
test['EndDay'] = test['Policy_End_Date'].dt.day
test['FirstDay'] = test['First_Transaction_Date'].dt.day

# %%
test = test.sort_values(by='Policy_Start_Date')
test
# Out:
#               ID Policy_Start_Date Policy_End_Date  Gender   Age  \
# 195   ID_6JEYVLP        2010-01-01      2010-12-31    Male  35.0
# 379   ID_BX1PNZ6        2010-01-01      2011-05-31   Other  93.0
# 248   ID_83NJU2D        2010-01-01      2010-12-31    Male  41.0
# 882   ID_Q6GKOAQ        2010-01-02      2011-01-01  Female  45.0
# 1092  ID_WB3E64W        2010-01-02      2011-01-01    Male  66.0
# ...          ...               ...             ...     ...   ...
# 116   ID_3VAANJU        2010-12-30      2011-12-29  Female  41.0
# 307   ID_A1YSYCA        2010-12-30      2011-12-29    Male  45.0
# 1115  ID_X7F8710        2010-12-31      2011-12-30    Male  38.0
# 781   ID_MZPS3W5        2010-12-31      2011-07-10    Male  34.0
# 1047  ID_V1RSMQM        2010-12-31      2011-12-30    Male  51.0
#
#      First_Transaction_Date  No_Pol Car_Category Subject_Car_Colour  \
# 195              2010-01-01       1         JEEP                NaN
# 379              2010-01-01       7          NaN        As Attached
# 248              2010-01-01       4          NaN                NaN
# 882              2010-01-02       1         JEEP              White
# 1092             2010-01-02       1       Saloon                NaN
# ...                     ...     ...          ...                ...
# 116              2010-12-30       1          NaN                NaN
# 307              2010-12-30       1          NaN                NaN
# 1115             2010-12-31       3       Saloon             Silver
# 781              2010-12-31       1          NaN        As Attached
# 1047             2010-12-31       1          NaN              Brown
#
#      Subject_Car_Make         LGA_Name       State  ProductName  StartMonth  \
# 195             ACURA              NaN         NaN      CarSafe           1
# 379             Honda     Lagos Island       Lagos      CarSafe           1
# 248               NaN  Victoria Island       Lagos        Muuve           1
# 882              Ford              NaN         NaN  Car Classic           1
# 1092           TOYOTA              NaN         NaN      CarSafe           1
# ...               ...              ...         ...          ...         ...
# 116               NaN              NaN         NaN  Car Classic          12
# 307               NaN              NaN         NaN      CarSafe          12
# 1115          Hyundai       Obia/Akpor  Obia-Akpor  Car Classic          12
# 781            TOYOTA          Onitsha     Anambra  Car Classic          12
# 1047      Range Rover  Victoria Island       Lagos  Car Classic          12
#
#       EndMonth  FirstMonth  StartDay  EndDay  FirstDay
# 195         12           1         1      31         1
# 379          5           1         1      31         1
# 248         12           1         1      31         1
# 882          1           1         2       1         2
# 1092         1           1         2       1         2
# ...        ...         ...       ...     ...       ...
# 116         12          12        30      29        30
# 307         12          12        30      29        30
# 1115        12          12        31      30        31
# 781          7          12        31      10        31
# 1047        12          12        31      30        31
#
# [1202 rows x 19 columns]

# %%
test
# Out:
#               ID Policy_Start_Date Policy_End_Date  Gender   Age  \
# 195   ID_6JEYVLP        2010-01-01      2010-12-31    Male  35.0
# 379   ID_BX1PNZ6        2010-01-01      2011-05-31   Other  93.0
# 248   ID_83NJU2D        2010-01-01      2010-12-31    Male  41.0
# 882   ID_Q6GKOAQ        2010-01-02      2011-01-01  Female  45.0
# 1092  ID_WB3E64W        2010-01-02      2011-01-01    Male  66.0
# ...          ...               ...             ...     ...   ...
# 116   ID_3VAANJU        2010-12-30      2011-12-29  Female  41.0
# 307   ID_A1YSYCA        2010-12-30      2011-12-29    Male  45.0
# 1115  ID_X7F8710        2010-12-31      2011-12-30    Male  38.0
# 781   ID_MZPS3W5        2010-12-31      2011-07-10    Male  34.0
# 1047  ID_V1RSMQM        2010-12-31      2011-12-30    Male  51.0
#
#      First_Transaction_Date  No_Pol Car_Category Subject_Car_Colour  \
# 195              2010-01-01       1         JEEP        As Attached
# 379              2010-01-01       7         JEEP        As Attached
# 248              2010-01-01       4         JEEP              White
# 882              2010-01-02       1         JEEP              White
# 1092             2010-01-02       1       Saloon        As Attached
# ...                     ...     ...          ...                ...
# 116              2010-12-30       1       Saloon             Silver
# 307              2010-12-30       1       Saloon             Silver
# 1115             2010-12-31       3       Saloon             Silver
# 781              2010-12-31       1          NaN        As Attached
# 1047             2010-12-31       1          NaN              Brown
#
#      Subject_Car_Make         LGA_Name       State  ProductName
# 195             ACURA     Lagos Island       Lagos      CarSafe
# 379             Honda     Lagos Island       Lagos      CarSafe
# 248              Ford  Victoria Island       Lagos        Muuve
# 882              Ford  Victoria Island       Lagos  Car Classic
# 1092           TOYOTA  Victoria Island       Lagos      CarSafe
# ...               ...              ...         ...          ...
# 116           Hyundai       Obia/Akpor  Obia-Akpor  Car Classic
# 307           Hyundai       Obia/Akpor  Obia-Akpor      CarSafe
# 1115          Hyundai       Obia/Akpor  Obia-Akpor  Car Classic
# 781            TOYOTA          Onitsha     Anambra  Car Classic
# 1047      Range Rover  Victoria Island       Lagos  Car Classic
#
# [1202 rows x 13 columns]

# %%
def backfill_data(data, columns):
    for column in columns:
        data[column] = data[column].fillna(method='bfill')
    return data

backfill_columns = ['Car_Category', 'Subject_Car_Colour', 'Subject_Car_Make', 'LGA_Name', 'State']

# test = test.drop(columns=['StartMonth', 'EndMonth', 'FirstMonth', 'StartDay', 'EndDay', 'FirstDay'])
    
backfilled_test = backfill_data(test, backfill_columns)

print("Original Data:")
print(test)
print("\nBackfilled Data:")
print(backfilled_test)

backfilled_test.to_csv('../data/backfilled_test.csv', index=False)
# Out:
# Original Data:
#               ID Policy_Start_Date Policy_End_Date  Gender   Age  \
# 195   ID_6JEYVLP        2010-01-01      2010-12-31    Male  35.0
# 379   ID_BX1PNZ6        2010-01-01      2011-05-31   Other  93.0
# 248   ID_83NJU2D        2010-01-01      2010-12-31    Male  41.0
# 882   ID_Q6GKOAQ        2010-01-02      2011-01-01  Female  45.0
# 1092  ID_WB3E64W        2010-01-02      2011-01-01    Male  66.0
# ...          ...               ...             ...     ...   ...
# 116   ID_3VAANJU        2010-12-30      2011-12-29  Female  41.0
# 307   ID_A1YSYCA        2010-12-30      2011-12-29    Male  45.0
# 1115  ID_X7F8710        2010-12-31      2011-12-30    Male  38.0
# 781   ID_MZPS3W5        2010-12-31      2011-07-10    Male  34.0
# 1047  ID_V1RSMQM        2010-12-31      2011-12-30    Male  51.0
#
#      First_Transaction_Date  No_Pol Car_Category Subject_Car_Colour  \
# 195              2010-01-01       1         JEEP        As Attached
# 379              2010-01-01       7         JEEP        As Attached
# 248              2010-01-01       4         JEEP              White
# 882              2010-01-02       1         JEEP              White
# 1092             2010-01-02       1       Saloon        As Attached
# ...                     ...     ...          ...                ...
# 116              2010-12-30       1       Saloon             Silver
# 307              2010-12-30       1       Saloon             Silver
# 1115             2010-12-31       3       Saloon             Silver
# 781              2010-12-31       1          NaN        As Attached
# 1047             2010-12-31       1          NaN              Brown
#
#      Subject_Car_Make         LGA_Name       State  ProductName
# 195             ACURA     Lagos Island       Lagos      CarSafe
# 379             Honda     Lagos Island       Lagos      CarSafe
# 248              Ford  Victoria Island       Lagos        Muuve
# 882              Ford  Victoria Island       Lagos  Car Classic
# 1092           TOYOTA  Victoria Island       Lagos      CarSafe
# ...               ...              ...         ...          ...
# 116           Hyundai       Obia/Akpor  Obia-Akpor  Car Classic
# 307           Hyundai       Obia/Akpor  Obia-Akpor      CarSafe
# 1115          Hyundai       Obia/Akpor  Obia-Akpor  Car Classic
# 781            TOYOTA          Onitsha     Anambra  Car Classic
# 1047      Range Rover  Victoria Island       Lagos  Car Classic
#
# [1202 rows x 13 columns]
#
# Backfilled Data:
#               ID Policy_Start_Date Policy_End_Date  Gender   Age  \
# 195   ID_6JEYVLP        2010-01-01      2010-12-31    Male  35.0
# 379   ID_BX1PNZ6        2010-01-01      2011-05-31   Other  93.0
# 248   ID_83NJU2D        2010-01-01      2010-12-31    Male  41.0
# 882   ID_Q6GKOAQ        2010-01-02      2011-01-01  Female  45.0
# 1092  ID_WB3E64W        2010-01-02      2011-01-01    Male  66.0
# ...          ...               ...             ...     ...   ...
# 116   ID_3VAANJU        2010-12-30      2011-12-29  Female  41.0
# 307   ID_A1YSYCA        2010-12-30      2011-12-29    Male  45.0
# 1115  ID_X7F8710        2010-12-31      2011-12-30    Male  38.0
# 781   ID_MZPS3W5        2010-12-31      2011-07-10    Male  34.0
# 1047  ID_V1RSMQM        2010-12-31      2011-12-30    Male  51.0
#
#      First_Transaction_Date  No_Pol Car_Category Subject_Car_Colour  \
# 195              2010-01-01       1         JEEP        As Attached
# 379              2010-01-01       7         JEEP        As Attached
# 248              2010-01-01       4         JEEP              White
# 882              2010-01-02       1         JEEP              White
# 1092             2010-01-02       1       Saloon        As Attached
# ...                     ...     ...          ...                ...
# 116              2010-12-30       1       Saloon             Silver
# 307              2010-12-30       1       Saloon             Silver
# 1115             2010-12-31       3       Saloon             Silver
# 781              2010-12-31       1          NaN        As Attached
# 1047             2010-12-31       1          NaN              Brown
#
#      Subject_Car_Make         LGA_Name       State  ProductName
# 195             ACURA     Lagos Island       Lagos      CarSafe
# 379             Honda     Lagos Island       Lagos      CarSafe
# 248              Ford  Victoria Island       Lagos        Muuve
# 882              Ford  Victoria Island       Lagos  Car Classic
# 1092           TOYOTA  Victoria Island       Lagos      CarSafe
# ...               ...              ...         ...          ...
# 116           Hyundai       Obia/Akpor  Obia-Akpor  Car Classic
# 307           Hyundai       Obia/Akpor  Obia-Akpor      CarSafe
# 1115          Hyundai       Obia/Akpor  Obia-Akpor  Car Classic
# 781            TOYOTA          Onitsha     Anambra  Car Classic
# 1047      Range Rover  Victoria Island       Lagos  Car Classic
#
# [1202 rows x 13 columns]

# %%
backfilled_test
# Out:
#               ID Policy_Start_Date Policy_End_Date  Gender   Age  \
# 195   ID_6JEYVLP        2010-01-01      2010-12-31    Male  35.0
# 379   ID_BX1PNZ6        2010-01-01      2011-05-31   Other  93.0
# 248   ID_83NJU2D        2010-01-01      2010-12-31    Male  41.0
# 882   ID_Q6GKOAQ        2010-01-02      2011-01-01  Female  45.0
# 1092  ID_WB3E64W        2010-01-02      2011-01-01    Male  66.0
# ...          ...               ...             ...     ...   ...
# 116   ID_3VAANJU        2010-12-30      2011-12-29  Female  41.0
# 307   ID_A1YSYCA        2010-12-30      2011-12-29    Male  45.0
# 1115  ID_X7F8710        2010-12-31      2011-12-30    Male  38.0
# 781   ID_MZPS3W5        2010-12-31      2011-07-10    Male  34.0
# 1047  ID_V1RSMQM        2010-12-31      2011-12-30    Male  51.0
#
#      First_Transaction_Date  No_Pol Car_Category Subject_Car_Colour  \
# 195              2010-01-01       1         JEEP        As Attached
# 379              2010-01-01       7         JEEP        As Attached
# 248              2010-01-01       4         JEEP              White
# 882              2010-01-02       1         JEEP              White
# 1092             2010-01-02       1       Saloon        As Attached
# ...                     ...     ...          ...                ...
# 116              2010-12-30       1       Saloon             Silver
# 307              2010-12-30       1       Saloon             Silver
# 1115             2010-12-31       3       Saloon             Silver
# 781              2010-12-31       1          NaN        As Attached
# 1047             2010-12-31       1          NaN              Brown
#
#      Subject_Car_Make         LGA_Name       State  ProductName  StartMonth  \
# 195             ACURA     Lagos Island       Lagos      CarSafe           1
# 379             Honda     Lagos Island       Lagos      CarSafe           1
# 248              Ford  Victoria Island       Lagos        Muuve           1
# 882              Ford  Victoria Island       Lagos  Car Classic           1
# 1092           TOYOTA  Victoria Island       Lagos      CarSafe           1
# ...               ...              ...         ...          ...         ...
# 116           Hyundai       Obia/Akpor  Obia-Akpor  Car Classic          12
# 307           Hyundai       Obia/Akpor  Obia-Akpor      CarSafe          12
# 1115          Hyundai       Obia/Akpor  Obia-Akpor  Car Classic          12
# 781            TOYOTA          Onitsha     Anambra  Car Classic          12
# 1047      Range Rover  Victoria Island       Lagos  Car Classic          12
#
#       EndMonth  FirstMonth  StartDay  EndDay  FirstDay
# 195         12           1         1      31         1
# 379          5           1         1      31         1
# 248         12           1         1      31         1
# 882          1           1         2       1         2
# 1092         1           1         2       1         2
# ...        ...         ...       ...     ...       ...
# 116         12          12        30      29        30
# 307         12          12        30      29        30
# 1115        12          12        31      30        31
# 781          7          12        31      10        31
# 1047        12          12        31      30        31
#
# [1202 rows x 19 columns]

# %%
# Check if there any missing values in train set
ax = backfilled_test.isna().sum().sort_values().plot(kind = 'barh', figsize = (8, 5))
plt.title('Percentage of Missing Values Per Column in Train Set', fontdict={'size':15})
for p in ax.patches:
    percentage ='{:,.0f}%'.format((p.get_width()/backfilled_test.shape[0])*100)
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))
